# %%
# %matplotlib inline
# Out:
# /home/whanlon/.local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import xmaxCompat

# %%
x = xmaxCompat.xmaxCompat()

# %%
x.main(18.2, 18.4)
# Out:
# Energy range: [ 18.2 18.4 ] log10(E/eV)
# Hanlon Xmax
# chi2/dof = 23527.5120701 / ( 33  -  4 ) ( 811.293519658 )
# N 	=	2622.19508583 +/- 228.450263592
# t0 	=	690.719410906 +/- 1.96766716278
# lambda 	=	54.0134032951 +/- 2.81734121577
# sigma 	=	22.4668640036 +/- 1.42331200611
#
#
# Ikeda Xmax
# chi2/dof = 6242.18518477 / ( 33  -  4 ) ( 215.247764992 )
# N 	=	737.19660535 +/- 66.7450571562
# t0 	=	694.365490778 +/- 2.01827165906
# lambda 	=	51.9444536789 +/- 2.65939453744
# sigma 	=	22.8344543622 +/- 1.49518174915
#
#
#  <Hanlon Xmax> = 748.178141302
#  <Ikeda Xmax> = 750.367677345
# shift = -2.18953604265
#
#
# CvM test statistic: 1.061427
# p-value: 0.00325407918713

# %%
x.main(18.4, 18.6)
# Out:
# Energy range: [ 18.4 18.6 ] log10(E/eV)
# Hanlon Xmax
# chi2/dof = 13235.8254747 / ( 38  -  4 ) ( 389.288984549 )
# N 	=	5986.54730873 +/- 2809.41481525
# t0 	=	714.440023391 +/- 3.73278215399
# lambda 	=	29.6896986668 +/- 3.41750893176
# sigma 	=	29.4967367395 +/- 2.4950929576
#
#
# Ikeda Xmax
# chi2/dof = 3600.90388126 / ( 35  -  4 ) ( 116.158189718 )
# N 	=	514.63388257 +/- 83.4856512819
# t0 	=	707.044043695 +/- 2.928404554
# lambda 	=	45.5817711465 +/- 3.663726268
# sigma 	=	23.1874550535 +/- 2.38945096813
#
#
#  <Hanlon Xmax> = 746.037465968
#  <Ikeda Xmax> = 755.246244677
# shift = -9.20877870911
#
#
# CvM test statistic: 4.419615
# p-value: 0.0

# %%
x.main(18.6, 18.8)
# Out:
# Energy range: [ 18.6 18.8 ] log10(E/eV)
# Hanlon Xmax
# chi2/dof = 6347.176798 / ( 34  -  4 ) ( 211.572559933 )
# N 	=	1022.69733991 +/- 193.60726934
# t0 	=	714.971825262 +/- 3.27761451375
# lambda 	=	44.7386196618 +/- 3.77818526459
# sigma 	=	26.8481727152 +/- 2.17063273513
#
#
# Ikeda Xmax
# chi2/dof = 1809.37866267 / ( 31  -  4 ) ( 67.0140245434 )
# N 	=	381.7014346 +/- 111.356828271
# t0 	=	721.346544626 +/- 3.91007561671
# lambda 	=	39.7780832568 +/- 4.33853084648
# sigma 	=	28.4904229149 +/- 2.58163650887
#
#
#  <Hanlon Xmax> = 758.484768467
#  <Ikeda Xmax> = 761.1670267
# shift = -2.68225823283
#
#
# CvM test statistic: 1.03506
# p-value: 0.00381336855418

# %%
x.main(18.8, 19.0)
# Out:
# Energy range: [ 18.8 19.0 ] log10(E/eV)
# Hanlon Xmax
# chi2/dof = 3160.60986401 / ( 35  -  4 ) ( 101.955156904 )
# N 	=	912.125434859 +/- 264.107154157
# t0 	=	727.983317017 +/- 2.92304054897
# lambda 	=	38.2515114562 +/- 3.14602203496
# sigma 	=	33.9016525144 +/- 2.14808027129
#
#
# Ikeda Xmax
# chi2/dof = 993.892362272 / ( 35  -  4 ) ( 32.0610439443 )
# N 	=	245.193759874 +/- 54.2436824805
# t0 	=	729.942124731 +/- 2.60808745765
# lambda 	=	38.4952975554 +/- 2.75882171103
# sigma 	=	30.7512965514 +/- 1.82683813182
#
#
#  <Hanlon Xmax> = 764.704317196
#  <Ikeda Xmax> = 766.820012011
# shift = -2.1156948154
#
#
# CvM test statistic: 0.251869
# p-value: 0.186147015458
